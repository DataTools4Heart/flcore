# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io

# %%
# !ls
# Out:
# metadata.json  part.parquet  Untitled.ipynb

# %%
#dat_json = pd.read_json("metadata.json")
#rawdata = open("metadata.json", "r", encoding="utf-8")

#dat_json = pd.read_json(io.StringIO("metadta.json"))
dat_parq = pd.read_parquet("part.parquet")
#dat
#rawdata
dat_parq #.keys()
# Out:
#                                Patient                         Encounter  \
# 0     0675d794dd9b3d2a0d1505922a04ab8f  ec2b239d50e1c2f353d2279f57994fab
# 1     3b9d45aa478bcde40f52f81fbf108ad6  0f21dd1be7b7d1eb94006c6714b0435b
# 2     3b9d45aa478bcde40f52f81fbf108ad6  8ab80f619f48c980a5cb7ab965393225
# 3     410557ff923dcae499fd319b4597b343  8ccd4fba54cfa0f081c5fd2acb0d8ae7
# 4     6f7f0b1c52e01858fb2c464c75c1bf48  9637323359a0eda4149a98bed5be8b2e
# ...                                ...                               ...
# 3294  ca1a9172718f87ac5c3732dea9220996  eb93e2dca681d02cf8de233ac4f3fffc
# 3295  cfe69d37f63f25d4fdf8720ab839305f  539dc637616680ad387cb7e9e6029660
# 3296  cfe69d37f63f25d4fdf8720ab839305f  f0f8344c8032e4c12553977cde647862
# 3297  f1c697e749dbe52bb8b34aec7f0399ce  650a93dcafbdb806841a0e389e77f9d7
# 3298  f1c697e749dbe52bb8b34aec7f0399ce  dc2f9003924f75c3b6b32fb6618751fa
#
#      referenceTimePoint eligibilityEventTime eligibilityExitTime  \
# ...

# %%
for i in dat_parq.keys():  #.mean()
    print(i)
# Out:
# Patient
# Encounter
# referenceTimePoint
# eligibilityEventTime
# eligibilityExitTime
# nextReferenceTimePoint
# previousReferenceTimePoint
# encounters_encounterClass
# encounters_admissionYear
# encounters_primaryReasonCode
# patient_demographics_gender
# patient_demographics_age
# vital_signs_weight_value_last
# vital_signs_weight_value_min
# vital_signs_weight_value_stddev
# vital_signs_weight_value_avg
# vital_signs_weight_value_max
# vital_signs_weight_value_first
# vital_signs_height_value_last
# vital_signs_height_value_min
# vital_signs_height_value_stddev
# vital_signs_height_value_avg
# vital_signs_height_value_max
# vital_signs_height_value_first
# vital_signs_systolicBp_value_last
# vital_signs_systolicBp_value_min
# vital_signs_systolicBp_value_stddev
# vital_signs_systolicBp_value_avg
# vital_signs_systolicBp_value_max
# vital_signs_systolicBp_value_first
# vital_signs_diastolicBp_value_last
# vital_signs_diastolicBp_value_min
# vital_signs_diastolicBp_value_stddev
# ...

# %%
dat_parq["lab_results_triGly_value_min"].dropna()
# Out:
# 26      0.93
# 129     0.91
# 214     0.87
# 238     1.19
# 318     1.49
# 483     2.69
# 497     1.21
# 529     0.63
# 583     0.74
# 587     1.08
# 700     1.10
# 723     0.90
# 727     1.60
# 739     1.66
# 774     1.42
# 804     0.74
# 819     0.93
# 1142    1.18
# 1189    0.65
# 1412    0.84
# 1419    1.08
# 1450    1.16
# 1625    1.55
# 1746    1.09
# 1789    1.08
# 1822    1.31
# 1890    2.05
# 2036    1.22
# 2209    1.43
# 2298    1.67
# 2595    1.19
# 2596    1.62
# 2753    0.76
# 2778    1.23
# 2826    1.21
# 2862    0.55
# 2928    1.01
# 2981    1.24
# 3053    0.89
# 3061    0.61
# 3122    1.26
# Name: lab_results_triGly_value_min, dtype: float64

# %%
import json

# Open and read the JSON file
with open('metadata.json', 'r') as file:
    data = json.load(file)

# Print the data

# %%
data["entries"][0].keys()
# Out:
# dict_keys(['resourceType', 'id', 'meta', 'url', 'name', 'until', 'population', 'featureSet', 'size'])

# %%
data["entries"][0]["id"]
# Out:
# 'd5b4d69c-575b-4e3a-8c6b-a6aba345e430'

# %%
data["entries"][0]["featureSet"].keys()
# Out:
# dict_keys(['url', 'title', 'description', 'referenceTimePoints', 'features', 'outcomes'])

# %%
data["entries"][0]["featureSet"]["features"]
# Out:
# [{'name': 'encounters_encounterClass',
#   'description': 'Type of encounter (emergency, impatient, outpatient, etc)',
#   'dataType': 'NOMINAL',
#   'generatedDescription': ['latest value', 'until that time point'],
#   'statistics': {'numOfNotNull': 3299,
#    'cardinality': 2,
#    'valueset': ['AMB', 'IMP'],
#    'cardinalityPerItem': {'AMB': 3220, 'IMP': 79}}},
#  {'name': 'encounters_admissionYear',
#   'description': 'Year of admission to hospital',
#   'dataType': 'NOMINAL',
#   'generatedDescription': ['latest value', 'until that time point'],
#   'statistics': {'numOfNotNull': 3299,
#    'cardinality': 24,
#    'valueset': ['2013',
#     '2003',
#     '2016',
#     '2019',
#     '2010',
#     '2007',
#     '2005',
#     '2014',
#     '2006',
#     '2004',
#     '2012',
#     '2015',
#     '2017',
#     '2009',
#     '2002',
#     '2021',
#     '2011',
#     '2023',
#     '2022',
#     '2000',
#     '2001',
#     '2020',
#     '2018',
#     '2008'],
# ...

# %%
numeric_columns = []
tipos = []
feat = data["entries"][0]["featureSet"]["features"]  #[10]["dataType"]
# len(data["entries"][0]["featureSet"]["features"]) # 297
# data["entries"][0]["featureSet"]["features"][0].keys() # dict_keys(['name', 'description', 'dataType', 'generatedDescription', 'statistics'])
for i in range(len(feat)):
    tipos.append(feat[i]["dataType"])
    if feat[i]["dataType"] == "NUMERIC" and feat[i]["statistics"]["numOfNotNull"] != 0:
        #print(i,feat[i]["statistics"]["min"],feat[i]["statistics"]["max"])
        print(i,feat[i]["name"])
        numeric_columns.append(feat[i]["name"])
    #if feat[i]["dataType"] == "BOOLEAN": # and feat[i]["statistics"]["numOfNotNull"] != 0:
    #    print(i)

set(tipos)
# Out:
# 4 patient_demographics_age
# 5 vital_signs_weight_value_last
# 6 vital_signs_weight_value_max
# 7 vital_signs_weight_value_avg
# 8 vital_signs_weight_value_min
# 9 vital_signs_weight_value_first
# 11 vital_signs_height_value_last
# 12 vital_signs_height_value_max
# 13 vital_signs_height_value_avg
# 14 vital_signs_height_value_min
# 15 vital_signs_height_value_first
# 41 lab_results_hemoglobin_value_avg
# 42 lab_results_hemoglobin_value_last
# 43 lab_results_hemoglobin_value_min
# 45 lab_results_hemoglobin_value_first
# 46 lab_results_hemoglobin_value_max
# 47 lab_results_ferritin_value_avg
# 48 lab_results_ferritin_value_last
# 49 lab_results_ferritin_value_min
# 51 lab_results_ferritin_value_first
# 52 lab_results_ferritin_value_max
# 53 lab_results_tfs_value_avg
# 54 lab_results_tfs_value_last
# 55 lab_results_tfs_value_min
# 57 lab_results_tfs_value_first
# 58 lab_results_tfs_value_max
# 95 lab_results_tropTHs_value_avg
# 96 lab_results_tropTHs_value_last
# ...

# %%
data["entries"][0]["featureSet"]["features"][197] #["statistics"]
# Out:
# {'name': 'symptoms_Ankle swelling_display_any',
#  'description': 'Whether the symptom is observed or not',
#  'dataType': 'BOOLEAN',
#  'generatedDescription': ["for Ankle swelling (pivot value = '267039000')",
#   'if any true',
#   'until that time point'],
#  'statistics': {'numOfNotNull': 3299, 'numOfTrue': 0}}

# %%
data["entries"][0]["featureSet"]["features"][0].keys()
# Out:
# dict_keys(['name', 'description', 'dataType', 'generatedDescription', 'statistics'])

# %%
data["entries"][0]["featureSet"]["features"][0]["description"]
# Out:
# 'Type of encounter (emergency, impatient, outpatient, etc)'

# %%
data["entries"][0]["featureSet"]["features"][4]["statistics"]["min"] #max avg
# Out:
# 25

# %%
dat_parq = pd.read_parquet("part.parquet")
dat_parq
# Out:
#                                Patient                         Encounter  \
# 0     0675d794dd9b3d2a0d1505922a04ab8f  ec2b239d50e1c2f353d2279f57994fab
# 1     3b9d45aa478bcde40f52f81fbf108ad6  0f21dd1be7b7d1eb94006c6714b0435b
# 2     3b9d45aa478bcde40f52f81fbf108ad6  8ab80f619f48c980a5cb7ab965393225
# 3     410557ff923dcae499fd319b4597b343  8ccd4fba54cfa0f081c5fd2acb0d8ae7
# 4     6f7f0b1c52e01858fb2c464c75c1bf48  9637323359a0eda4149a98bed5be8b2e
# ...                                ...                               ...
# 3294  ca1a9172718f87ac5c3732dea9220996  eb93e2dca681d02cf8de233ac4f3fffc
# 3295  cfe69d37f63f25d4fdf8720ab839305f  539dc637616680ad387cb7e9e6029660
# 3296  cfe69d37f63f25d4fdf8720ab839305f  f0f8344c8032e4c12553977cde647862
# 3297  f1c697e749dbe52bb8b34aec7f0399ce  650a93dcafbdb806841a0e389e77f9d7
# 3298  f1c697e749dbe52bb8b34aec7f0399ce  dc2f9003924f75c3b6b32fb6618751fa
#
#      referenceTimePoint eligibilityEventTime eligibilityExitTime  \
# ...

# %%
dat_parq[numeric_columns]
# Out:
#       patient_demographics_age  vital_signs_weight_value_last  \
# 0                           50                           80.0
# 1                           38                            NaN
# 2                           42                            NaN
# 3                           64                            NaN
# 4                           75                            NaN
# ...                        ...                            ...
# 3294                        80                            NaN
# 3295                        59                            NaN
# 3296                        50                            NaN
# 3297                        61                            NaN
# 3298                        58                            NaN
#
#       vital_signs_weight_value_max  vital_signs_weight_value_avg  \
# 0                             80.0                          80.0
# 1                              NaN                           NaN
# ...

# %%
numeric_columns = []
maxima = []
minima = []
avgs = []
feat = data["entries"][0]["featureSet"]["features"]
for i in range(len(feat)):
    tipos.append(feat[i]["dataType"])
    if feat[i]["dataType"] == "NUMERIC" and feat[i]["statistics"]["numOfNotNull"] != 0:
        #print(i,feat[i]["name"])
        name = feat[i]["name"]
        mini = feat[i]["statistics"]["min"]
        maxi = feat[i]["statistics"]["max"]
        avg  = feat[i]["statistics"]["avg"]

        numeric_columns.append(name)
        maxima.append({"max":maxi})
        minima.append({"max":mini})
        avgs.append({"max":avg})

numeric_columns
# Out:
# ['patient_demographics_age',
#  'vital_signs_weight_value_last',
#  'vital_signs_weight_value_max',
#  'vital_signs_weight_value_avg',
#  'vital_signs_weight_value_min',
#  'vital_signs_weight_value_first',
#  'vital_signs_height_value_last',
#  'vital_signs_height_value_max',
#  'vital_signs_height_value_avg',
#  'vital_signs_height_value_min',
#  'vital_signs_height_value_first',
#  'lab_results_hemoglobin_value_avg',
#  'lab_results_hemoglobin_value_last',
#  'lab_results_hemoglobin_value_min',
#  'lab_results_hemoglobin_value_first',
#  'lab_results_hemoglobin_value_max',
#  'lab_results_ferritin_value_avg',
#  'lab_results_ferritin_value_last',
#  'lab_results_ferritin_value_min',
#  'lab_results_ferritin_value_first',
#  'lab_results_ferritin_value_max',
#  'lab_results_tfs_value_avg',
#  'lab_results_tfs_value_last',
#  'lab_results_tfs_value_min',
#  'lab_results_tfs_value_first',
#  'lab_results_tfs_value_max',
#  'lab_results_tropTHs_value_avg',
# ...

# %%
for name in numeric_columns:
    print(dat_parq[name].dropna().mean())
#dat_parq["vital_signs_weight_value_max"].dropna()
# Out:
# 63.87359806001819
# 71.53846153846153
# 71.53846153846153
# 71.53846153846153
# 71.53846153846153
# 71.53846153846153
# 166.5
# 166.5
# 166.5
# 166.5
# 166.5
# 11.649095607235145
# 11.649095607235145
# 11.649095607235145
# 11.649095607235145
# 11.649095607235145
# 1469.6230769230772
# 1469.6230769230772
# 1469.6230769230772
# 1469.6230769230772
# 1469.6230769230772
# 1.5799999999999998
# 1.5799999999999998
# 1.5799999999999998
# 1.5799999999999998
# 1.5799999999999998
# 0.009
# 0.009
# 0.009
# 0.009
# 0.009
# 10.846153846153847
# 10.846153846153847
# 10.846153846153847
# 10.846153846153847
# 10.846153846153847
# 1.1699999999999997
# 1.1699999999999997
# 1.1699999999999997
# 1.1699999999999997
# 1.1699999999999997
# 5.077674418604651
# 5.077674418604651
# 5.077674418604651
# 5.077674418604651
# 5.077674418604651
# 1.5005263157894737
# 1.5005263157894737
# 1.5005263157894737
# 1.5005263157894737
# 1.5005263157894737
# 4.3619047619047615
# 4.3619047619047615
# 4.3619047619047615
# ...
